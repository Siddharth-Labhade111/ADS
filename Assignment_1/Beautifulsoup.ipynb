# %%
# %pip install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup

# College website URL
url = "https://www.sanjivanicoe.org.in"

# Send HTTP request
response = requests.get(url)

# Check if request is successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract page title
    title = soup.title.text
    print("Page Title:", title)

    print("\nAll Links:")
    for link in soup.find_all("a"):
        href = link.get("href")
        text = link.get_text(strip=True)
        print(text, "->", href)
else:
    print("Failed to fetch the webpage")
# Out:
# Requirement already satisfied: requests in d:\b.tech 3rd year\ads\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (4.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\b.tech 3rd year\ads\.venv\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Page Title: Sanjivani College of Engineering
#
# All Links:
#  -> /
# Contact -> /index.php/contact
# Apply online -> http://www.sanjivanicoe.org.in/files/coeweb/landing-page/college-of-engineering-in-kopargaon-admission-2020.html
#  -> /
# Home -> /
# About Us -> /index.php/about-us/our-institutes
# Our Inspiration -> /index.php/about-us/our-inspiration
# Chairman's Desk -> /index.php/about-us/chairman-s-desk
# Managing Trustee -> /index.php/about-us/managing-trustee
# Board Of Trustees -> /index.php/about-us/board-of-trustees
# Governing Body -> /index.php/about-us/sz-governing-body
# Our Institutes -> /index.php/about-us/our-institutes
# Directors's Desk -> /index.php/about-us/principal-s-desk
# Video Lectures -> /index.php/about-us/video-lectures
# Infrastructure -> /index.php/library/central-library
# Computer Center -> /index.php/about-us/infrastructure/computer-center
# Workshop -> /index.php/about-us/infrastructure/workshop
# Language Lab -> /index.php/about-us/infrastructure/language-lab
# Gymkhana -> /index.php/about-us/infrastructure/gymkhana
# Canteen -> /index.php/about-us/infrastructure/canteen
# Green Campus initiatives -> /index.php/about-us/infrastructure/green-campus-initiatives
# Hostel -> /index.php/about-us/infrastructure/hostel
# Professional Bodies -> /index.php/about-us/professional-bodies/i-e-e-e
# I.E.E.E. -> /index.php/about-us/professional-bodies/i-e-e-e
# C.S.I. -> /index.php/about-us/professional-bodies/c-s-i
# I.S.T.E. -> /index.php/about-us/professional-bodies/i-s-t-e
# S.A.E. -> /index.php/about-us/professional-bodies/s-a-e
# I.S.F. -> /index.php/about-us/professional-bodies/i-s-f
# IQAC -> /index.php/iqac
# IQAC Introduction -> /index.php/iqac/iqac-introduction
# AQAR Reports -> /index.php/iqac/aqar-reports
# Composition MOMS ATR -> /index.php/iqac/moms
# Quality Audit -> /index.php/iqac/quality-audit
# SSS Survey -> /index.php/iqac/sss-survey
# Best Practices -> /index.php/iqac/best-practices
# Institutional Distinctiveness -> /index.php/iqac/institutional-distinctiveness
# Maintaining and utilizing physical,academic and support facilities -> /index.php/iqac/maintaining-and-utilizing-physical-academic-and-support-facilities
# NAAC SSR -> /index.php/iqac/naac-ssr
# ISO -> /index.php/iqac/iso
# Mandatory Disclosure -> https://sanjivanicoe.org.in/images/Mandatory_Disclouser_2022_23_v2_March_2024_compressed.pdf
# Conferences, Seminars, Workshops on quality conducted -> /index.php/iqac/conferences-seminars-workshops-on-quality-conducted
# Collaborative quality initiatives -> /index.php/iqac/collaborative-quality-initiatives
# Participation in NIRF and other recognized ranking -> /index.php/iqac/participation-in-nirf-and-other-recognized-ranking
# Any other quality audit recognized by state, national or international agencies -> /index.php/iqac/any-other-quality-audit-recognized-by-state-national-or-international-agencies
# Orientation programme on quality issues for teachers and students -> /index.php/iqac/orientation-programme-on-quality-issues-for-teachers-and-students
# R & D -> /index.php/r-d
# Departments -> /index.php/department/information-technology/profile
# Civil Engineering -> /index.php/department/civil-engineering/profile
# Profile -> /index.php/department/civil-engineering/profile
# HOD's Desk -> /index.php/department/civil-engineering/hod-s-desk
# Faculty -> /index.php/department/civil-engineering/faculty
# Laboratory -> /index.php/department/civil-engineering/laboratory
# Achievements -> /index.php/department/civil-engineering/achievements
# Placement -> /index.php/department/civil-engineering/placement
# R & D -> /index.php/department/civil-engineering/r-d
# Curriculum -> /index.php/department/civil-engineering/curriculum-civil
# Research Centre -> /index.php/department/civil-engineering/research-centre
# Future Plans -> /index.php/department/civil-engineering/future-plans
# Association -> /index.php/department/civil-engineering/association/cesa
# CESA -> /index.php/department/civil-engineering/association/cesa
# Industrial Visits -> /index.php/department/civil-engineering/association/industrial-visits
# Newsletter -> /index.php/department/civil-engineering/civil-newsletter-menu
# Computer Engineering -> /index.php/department/computer-engineering/profile
# Profile -> /index.php/department/computer-engineering/profile
# HOD's Desk -> /index.php/department/computer-engineering/hod-s-desk
# Faculty -> /index.php/department/computer-engineering/faculty
# Laboratory -> /index.php/department/computer-engineering/laboratory
# Achievements -> /index.php/department/computer-engineering/achievements
# Association -> /index.php/department/computer-engineering/association/aces
# ACES -> /index.php/department/computer-engineering/association/aces
# Future Plans -> /index.php/department/computer-engineering/future-plans
# Placement -> /index.php/department/computer-engineering/placement
# R & D -> /index.php/department/computer-engineering/r-d
# Curriculum -> /index.php/department/computer-engineering/curriculum
# Best practices -> /index.php/department/computer-engineering/best-practices
# Newsletter -> /index.php/department/computer-engineering/newsletter
# Computer Engineering Boards of studies -> /index.php/department/computer-engineering/computer-engineering-boards-of-studies
# list of MOU Computer Engineering Department -> /index.php/department/computer-engineering/list-of-mou-computer-engineering-department
# Innovation in Teaching and learning -> /index.php/department/computer-engineering/innovation-in-teaching-and-learning
# Electrical Engineering -> /index.php/department/electrical-engineering/about-electrical-department
# About Electrical Department -> /index.php/department/electrical-engineering/about-electrical-department
# Profile -> /index.php/department/electrical-engineering/profile
# HOD’s Desk -> /index.php/department/electrical-engineering/hod-s-desk
# Faculty -> /index.php/department/electrical-engineering/faculty
# Laboratory -> /index.php/department/electrical-engineering/laboratory
# Association -> /index.php/department/electrical-engineering/association
# Achievements -> /index.php/department/electrical-engineering/achievements
# R & D -> /index.php/department/electrical-engineering/r-d
# Placement -> /index.php/department/electrical-engineering/placement
# Educational -> /index.php/department/electrical-engineering/educational
# Innovation -> /index.php/department/electrical-engineering/innovation
# Newsletter and magazine -> /index.php/department/electrical-engineering/newsletter-and-magazine
# Innovation in Teaching & Learning -> /index.php/department/electrical-engineering/innovation-in-teaching-learning
# Electrical Engineering Board of Studies -> /index.php/department/electrical-engineering/electrical-engineering-board-of-studies
# List of MOU -> /index.php/department/electrical-engineering/list-of-mou
# Curriculum -> /index.php/department/electrical-engineering/curriculum-electrical
# Electronics and Computer Engineering -> /index.php/department/e-tc-engineering/profile
# Profile -> /index.php/department/e-tc-engineering/profile
# HOD's Desk -> /index.php/department/e-tc-engineering/hod-s-desk
# Faculty -> /index.php/department/e-tc-engineering/faculty
# Laboratory -> /index.php/department/e-tc-engineering/laboratory
# curriculum -> /index.php/department/e-tc-engineering/curriculum
# Association -> /index.php/department/e-tc-engineering/association/i-e-e-e
# I.E.E.E. -> /index.php/department/e-tc-engineering/association/i-e-e-e
# ISF -> /index.php/department/e-tc-engineering/association/i-e-t-e
# E.T.E.S.A. -> /index.php/department/e-tc-engineering/association/e-t-e-s-a
# Achievements -> /index.php/department/e-tc-engineering/achievements
# Future Plans -> /index.php/department/e-tc-engineering/future-plans
# Placement -> /index.php/department/e-tc-engineering/placement
# R & D -> /index.php/department/e-tc-engineering/r-d
# Research Centre -> /index.php/department/e-tc-engineering/innovation
# Information Technology -> /index.php/department/information-technology/profile
# Profile -> /index.php/department/information-technology/profile
# HOD's Desk -> /index.php/department/information-technology/hod-s-desk
# Faculty -> /index.php/department/information-technology/faculty
# Laboratory -> /index.php/department/information-technology/laboratory
# Achievements -> /index.php/department/information-technology/achievements
# Association -> /index.php/department/information-technology/association/c-s-i
# C.S.I. -> /index.php/department/information-technology/association/c-s-i
# I.T.E.R.A -> /index.php/department/information-technology/association/i-t-e-r-a
# Future Plans -> /index.php/department/information-technology/future-plans
# Placement -> /index.php/department/information-technology/placement
# ICT Based Teaching -> /index.php/department/information-technology/ict-based-teaching
# R & D -> /index.php/department/information-technology/r-d
# Innovation -> /index.php/department/information-technology/innovation-01
# Curriculum -> /index.php/department/information-technology/it-curriculum
# Mechanical Engineering -> /index.php/department/mechanical-engineering/profile
# Profile -> /index.php/department/mechanical-engineering/profile
# HOD’s Desk -> /index.php/department/mechanical-engineering/hod-s-desk
# Faculty -> /index.php/department/mechanical-engineering/faculty
# Laboratory -> /index.php/department/mechanical-engineering/laboratory
# Achievements -> /index.php/department/mechanical-engineering/achievements
# Association -> /index.php/department/mechanical-engineering/association/m-e-s-a
# M.E.S.A. -> /index.php/department/mechanical-engineering/association/m-e-s-a
# S.A.E. -> /index.php/department/mechanical-engineering/association/s-a-e
# ISHRAE -> /index.php/department/mechanical-engineering/association/ishrae
# Future Plans -> /index.php/department/mechanical-engineering/future-plans
# R & D -> /index.php/department/mechanical-engineering/r-d
# Placement -> /index.php/department/mechanical-engineering/placement
# Placement -> /index.php/department/mechanical-engineering/placement/mech-placements-sbumenu
# Internship -> /index.php/department/mechanical-engineering/placement/internship
# Innovation -> /index.php/department/mechanical-engineering/innovation
# ICT Based Teaching -> /index.php/department/mechanical-engineering/ict-based-teaching
# Research Centre -> /index.php/department/mechanical-engineering/research-centre
# Curriculum & B.Tech (Honors) -> /index.php/department/mechanical-engineering/b-tech-honors
# NBA Records -> /index.php/department/mechanical-engineering/nba-records
# Faculty List -> /index.php/department/mechanical-engineering/nba-records/faculty-list
# Mech Newsletter -> /index.php/department/mechanical-engineering/mech-newsletter
# Mechatronics Engineering -> /index.php/department/mechatronics-engineering/hod-s-desk
# Profile -> /index.php/department/mechatronics-engineering/profile
# HOD’s Desk -> /index.php/department/mechatronics-engineering/hod-s-desk
# Faculty -> /index.php/department/mechatronics-engineering/faculty
# Laboratory -> /index.php/department/mechatronics-engineering/laboratory
# R & D -> /index.php/department/mechatronics-engineering/r-d
# Achievements -> /index.php/department/mechatronics-engineering/achievements
# Faculty Achievements -> /index.php/department/mechatronics-engineering/achievements/faculty-achievements
# Student Achievements -> /index.php/department/mechatronics-engineering/achievements/student-achievements
# Future Plans -> /index.php/department/mechatronics-engineering/future-plans
# Association -> /index.php/department/mechatronics-engineering/association
# Art Gallery -> /index.php/department/mechatronics-engineering/art-gallery
# Curriculum -> /index.php/department/mechatronics-engineering/curriculum
# Placement -> /index.php/department/mechatronics-engineering/placement
# Newsletter -> /index.php/department/mechatronics-engineering/newsletter-mechatronics
# Structural Engineering -> /index.php/department/structural-engineering/profile
# Profile -> /index.php/department/structural-engineering/profile
# HOD’s Desk -> /index.php/department/structural-engineering/hod-s-desk
# Faculty -> /index.php/department/structural-engineering/faculty
# Laboratory -> /index.php/department/structural-engineering/laboratory
# Achievements -> /index.php/department/structural-engineering/faculty-achievements
# Faculty Achievements -> /index.php/department/structural-engineering/faculty-achievements/achievements
# Student Achievements -> /index.php/department/structural-engineering/faculty-achievements/student-achievements
# Placement -> /index.php/department/structural-engineering/placement
# Research and Development Activities -> /index.php/department/structural-engineering/research-and-development-activities
# Curriculum -> /index.php/department/structural-engineering/r-d
# Future Plans -> /index.php/department/structural-engineering/future-plans
# Association -> /index.php/department/structural-engineering/association
# Industrial Visits -> /index.php/department/structural-engineering/industrial-visits
# Newsletter and Magazine -> /index.php/department/structural-engineering/newsletter-and-magazine
# MBA -> /index.php/department/mba/profile
# Profile -> /index.php/department/mba/profile
# HOD's Desk -> /index.php/department/mba/hod-s-desk
# Faculty -> /index.php/department/mba/faculty
# Library -> /index.php/department/mba/library
# Achievements -> /index.php/department/mba/achievements
# Placement -> /index.php/department/mba/placement
# R & D -> /index.php/department/mba/r-d
# Student Activities -> /index.php/department/mba/student-activities
# Curriculum -> /index.php/department/mba/curri-mba
# Engineering Science -> /index.php/department/engineering-science/profile
# Profile -> /index.php/department/engineering-science/profile
# Faculty -> /index.php/department/engineering-science/faculty
# Laboratory -> /index.php/department/engineering-science/laboratory
# Achievements -> /index.php/department/engineering-science/achievements
# Association -> /index.php/department/engineering-science/association/i-s-t-e
# I.S.T.E. -> /index.php/department/engineering-science/association/i-s-t-e
# Academic -> /index.php/academic
# Academic Bank of Credits (ABC) -> /index.php/academic/academic-bank-of-credits-abc
# Academic Calendar -> /index.php/academic/academic-calendar
# AICTE/UGC reference documents -> /index.php/academic/aicte-internship
# Course Structure -> /index.php/academic/syllabus-structure
# Five-Years Strategic plan 2020-25 -> /index.php/academic/five-years-strategic-plan-2020-25
# Rules and Regulations for BTech Honors -> /index.php/academic/rules-and-regulations-for-btech-honors
# Academic Council meeting -> /index.php/academic/academic-council-meeting
# BOS meeting -> /index.php/academic/bos-meeting
# Feedback -> /index.php/academic/feedback
# code of conduct -> /index.php/academic/code-of-conduct
# Central Library -> /index.php/library/central-library
# Central Library -> /index.php/library/central-library
# Periodical Section -> /index.php/library/periodical-section
# Digital Library -> /index.php/library/digital-library
# AICTE IDEA LAB -> /index.php/aicte-idea-lab
# Industry Interaction -> /index.php/industry-interaction/thought-leaders
# Thought Leaders -> /index.php/industry-interaction/thought-leaders
# My Story Board -> /index.php/industry-interaction/my-story-board
# EDP Cell -> /index.php/industry-interaction/edp-profile/profile
# Profile -> /index.php/industry-interaction/edp-profile/profile
# Placements -> /index.php/placements/placement-overviews
# Placement Overviews -> /index.php/placements/placement-overviews
# Our Top Placements -> /index.php/placements/our-top-placements
# Placement Process & Contacts -> /index.php/placements/placement-process-contacts
# Placement Information -> /index.php/placements/placement-information
# Valued Recruiters -> /index.php/placements/valued-recruiters
# Valued training & MOU partners -> /index.php/placements/valued-training-mou-partners
# Placement Statistics Yearwise -> /index.php/placements/placement-statistics
# Placement Terms & Conditions -> /index.php/placements/placement-terms-conditions
# Admissions -> /index.php/admissions/courses-offered
# DSY Against CAP -> /index.php/admissions/dsy-against-cap
# DSY Final Merit List -> https://drive.google.com/file/d/11w78aXJKrfS-lzbHhPiGHA4H3w4j2D3Z/view?usp=drive_link
# Final FY B.Tech CET Score Merit List -> https://drive.google.com/file/d/1iDyW31tzV6-4XxfUs00y_ZmOEn8Rk4xp/view?usp=sharing
# Final MBA Merit List -> https://drive.google.com/file/d/1Igz95eaT2zs-wnJsAM01OgTiIppZR2AE/view?usp=sharing
# Courses Offered -> /index.php/admissions/courses-offered
# First Year Engineering -> /index.php/admissions/first-year-engineering
# Direct Second Year Admissions -> /index.php/admissions/direct-second-year-admissions
# Postgraduate Admissions -> /index.php/admissions/postgraduate-admissions
# M.Tech Merit List 2025-2026 -> https://drive.google.com/file/d/1WuCVlTLxTqtbCFI37XaAE8cvaeFs9iCA/view?usp=drive_link
# FY B.Tech JEE Score Merit List -> https://drive.google.com/file/d/155_y_4V_Juepzas5bsV0w1-yyguIQ2Wj/view?usp=sharing
# FY B.Tech Diploma Merit List -> https://drive.google.com/file/d/1_YKw9TEzgQVNrZS-OIe8AugEWWd1s_w4/view?usp=drive_link
# Student Zone -> /index.php/student-zone/sz-student-council
# Committees & Cells -> #
# College Development Committee (CDC) -> /index.php/student-zone/committees/sz-college-development
# Student Grievance Redressal Committee -> /index.php/student-zone/committees/sz-graviance-commitee-2018
# SC / ST committee -> /index.php/student-zone/committees/sz-sc-st
# Library Committee -> /index.php/student-zone/committees/library-committee
# Internal Complaint Committee -> /index.php/student-zone/committees/internal-complaint-committee
# Equal Opportunity Cell -> /index.php/student-zone/committees/equal-opportunity-cell
# Divyang Cell -> /index.php/student-zone/committees/divyang-cell
# Student Council -> /index.php/student-zone/sz-student-council
# Earn & Learn Scheme -> /index.php/student-zone/sz-earn-learn
# Prevention of Sexual Harassment of Woman at workplace -> /index.php/student-zone/sz-sexual-hrass
# Anti Ragging Committee -> /index.php/student-zone/sz-anti-ragging
# Deans -> /index.php/student-zone/deans
# National Service Scheme -> /index.php/student-zone/national-service-scheme
# Academic Council Member -> /index.php/student-zone/academic-council-member
# Scholarship -> /index.php/student-zone/brij-scholarship
# Exam Section -> /index.php/exam-section
# About -> /index.php/exam-section/about
# Office Staff -> /index.php/exam-section/office-staff
# Examination ordinances -> /index.php/exam-section/examination-ordinances
# Exam Schedule -> /index.php/exam-section/exam-schedule
# FAQs -> /index.php/exam-section/faqs
# Roles of Examination section -> /index.php/exam-section/roles-of-examination-section
# SAP Training -> /index.php/sap-training
# About SAP -> /index.php/sap-training/about-sap
# SAP Advance Module -> /index.php/sap-training/sap-advance-module
# PGDERP -> /index.php/sap-training/pgderp
# SIRD -> /index.php/sird
# ERP login -> https://sanjivani.edupluscampus.com/
# Faculty login -> https://sanjivani.edupluscampus.com/
# Student login -> https://mysanjivani.edupluscampus.com/
# Newsletter -> /index.php/newsletter
# NAAC -> /index.php/naac
# Screen Reader -> /index.php/screen-reader
# Events & News -> /index.php/events
# Events Organized -> https://sanjivanicoe.org.in/files/coeweb/
# Upcoming Events -> https://sanjivanicoe.org.in/files/coeweb/
# News -> https://sanjivanicoe.org.in/index.php/news
# Gallery View -> /index.php/gallery-view
# Induction Programme -> /index.php/gallery-view/induction-programme
# College Campus -> /index.php/gallery-view/college-campus
# Hostel Tour -> /index.php/gallery-view/hostel-gallery
# Security Tour -> /index.php/gallery-view/security-tour
# Transport Tour -> /index.php/gallery-view/transport-tour
# Tech Fest 25 -> /index.php/gallery-view/tech-fest-25
# Videos -> /index.php/gallery-view/videos
# Contact -> /index.php/contact
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# Click here for more Placement NEWS -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# 📢 Explore More Placement Updates -> https://sanjivanicoe.org.in/index.php/news
# Apply online -> http://www.sanjivanicoe.org.in/files/coeweb/landing-page/college-of-engineering-in-kopargaon-admission-2020.html
# Click to register -> https://docs.google.com/forms/d/e/1FAIpQLSe3wLgGmXqPG8XmiGF9-D6yB7-AA3VcowfV8iJzdkpPkMHCuQ/viewform
# 📥 Click Here to download -> /images/pdf/Fee_Structure_2025_26.pdf
# Read more -> /images/ISTE_Award_2023.jpg
# Read More -> /index.php/key-highlights
# Civil Engineering -> https://www.sanjivanicoe.org.in/index.php/department/civil-engineering/profile
# Computer Engineering -> https://www.sanjivanicoe.org.in/index.php/department/computer-engineering/profile
# Electrical Engineering -> https://www.sanjivanicoe.org.in/index.php/department/electrical-engineering/about-electrical-department
# Electronics and Computer Engineering -> https://www.sanjivanicoe.org.in/index.php/department/e-tc-engineering/profile
# Information Technology -> https://www.sanjivanicoe.org.in/index.php/department/information-technology/profile
# Mechanical Engineering -> https://www.sanjivanicoe.org.in/index.php/department/mechanical-engineering/profile
# Mechatronics Engineering -> https://www.sanjivanicoe.org.in/index.php/department/mechatronics-engineering/hod-s-desk
# Structural Engineering -> https://www.sanjivanicoe.org.in/index.php/department/structural-engineering/profile
# MBA -> https://www.sanjivanicoe.org.in/index.php/department/mba/profile
# View All -> /index.php/news
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read More -> /index.php/proud-alumni
# Read more -> None
# View All -> /index.php/alumni-bytes
# Read More -> /index.php/life-sanjivani
# Read More -> /index.php/projects
# Read More -> /index.php/collaborations
#  -> https://www.facebook.com/SanjivaniGroupofInstitutes/
#  -> https://twitter.com/Sanjivani_Group?lang=en
#  -> https://www.linkedin.com/uas/login?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fschool%2F7800380%2Fadmin%2F
#  -> https://www.instagram.com/sanjivanigroupofinstitutes/?hl=en
#  -> #
# powered by dimakh consultants -> https://www.dimakhconsultants.com/
# Our Institutes -> /index.php/about-us/our-institutes
# NIRF -> /index.php/placements/placement-overviews?id=160
# Training and Placement -> /index.php/placements/placement-overviews
# Prospectus/Brochure -> /images/sap/SGI.pdf
# Gallery -> /index.php/gallery-view/college-campus
# Webmail -> https://www.gmail.com
# Human Asset Policy Manual -> /images/pdf/audit/SCOE_HA_Policy.pdf
# SIMS -> http://34.237.253.179/sims
# FRA -> /index.php/fra
# Spoken Tutorial -> /images/pdf/Spoken_Tutorial.pdf
# NAAC -> /index.php/naac-record
# WELFARE SCHEMES -> /index.php/welfare-schemes
# Video Lectures -> /index.php/about-us/video-lectures
# Alumni -> https://alumni.sanjivani.org.in/
# Apply for Transcript -> https://sanjivani.truecopy.in/v2/files/submitdoctranscript.tc
# Student Verification -> https://sanjivani.truecopy.in/v2/files/submitdocverify.tc
# R & D Acitivities -> /index.php/r-d-activities
# Grievances -> /index.php/grievances
# Privacy Policy -> /index.php/privacy-policy
# AICTE EOA -> /images/pdf/1993%20to%202022%20AICTE%20EOA.pdf
# @sanjivani.org.in -> mailto:principalcoe@sanjivani.org.in
#  -> https://www.facebook.com/SanjivaniGroupofInstitutes/
#  -> https://twitter.com/Sanjivani_Group?lang=en
#  -> https://www.linkedin.com/uas/login?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fschool%2F7800380%2Fadmin%2F
#  -> https://www.instagram.com/sanjivanigroupofinstitutes/?hl=en
#  -> #
# powered by dimakh consultants -> https://www.dimakhconsultants.com/

# %%
import requests
from bs4 import BeautifulSoup
import csv

# -------------------------
# 1. Target URLs
# -------------------------
base_url = "https://www.sanjivanicoe.org.in"
pages = {
    "home": base_url,
    "director": base_url + "/index.php/about-us/principal-s-desk",
    "committee": base_url + "/index.php/student-zone/committees/library-committee",
    "academic_council": base_url + "/index.php/student-zone/academic-council-member",
    "hod_it": base_url + "/index.php/department/information-technology/hod-s-desk",
}

# Store scraped data
data = {
    "College Name": "",
    "Director": "",
    "Departments": [],
    "HOD IT": "",
    "Staff": []
}

# -------------------------
# 2. Fetch and Parse HTML
# -------------------------
def get_soup(url):
    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        return BeautifulSoup(r.text, "html.parser")
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

# -------------------------------------------------------
# 3. Scrape College Name + Departments from Home Page
# -------------------------------------------------------
soup_home = get_soup(pages["home"])
if soup_home:
    # College name (from title or header)
    title_tag = soup_home.title
    data["College Name"] = title_tag.text.strip() if title_tag else "Sanjivani College of Engineering"
    
    # Departments from menu
    depts = soup_home.select("ul li a")
    for d in depts:
        name = d.get_text(strip=True)
        if name and ("Engineering" in name or "Information Technology" in name):
            data["Departments"].append(name)

# -------------------------
# 4. Scrape Director
# -------------------------
soup_dir = get_soup(pages["director"])
if soup_dir:
    # Look for text near 'Director'
    text = soup_dir.get_text(separator="\n")
    for line in text.split("\n"):
        if "Director" in line and "Dr." in line:
            data["Director"] = line.strip()

# -----------------------------------------------
# 5. Scrape HOD IT
# -----------------------------------------------
soup_hod_it = get_soup(pages["hod_it"])
if soup_hod_it:
    text = soup_hod_it.get_text(separator="\n")
    # Look for a line that likely has an HOD name
    for line in text.split("\n"):
        if "Professor" in line or "Dr." in line or "HOD" in line:
            if "Information Technology" in line or "Head" in line:
                data["HOD IT"] = line.strip()

# -------------------------------------------------
# 6. Scrape Staff from committee pages
# -------------------------------------------------
# A combined approach: check academic council & library committee
for key in ["committee", "academic_council"]:
    soup_page = get_soup(pages[key])
    if soup_page:
        text = soup_page.get_text(separator="\n")
        for line in text.split("\n"):
            line_clean = line.strip()
            if line_clean and ("Dr." in line_clean or "Prof." in line_clean):
                data["Staff"].append(line_clean)

# Remove duplicates
data["Staff"] = list(set(data["Staff"]))

# -------------------------
# 7. Save to CSV
# -------------------------
with open("sanjivani_staff.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Category", "Details"])
    writer.writerow(["College Name", data["College Name"]])
    writer.writerow(["Director", data["Director"]])
    writer.writerow(["Departments", ", ".join(data["Departments"])])
    writer.writerow(["HOD IT", data["HOD IT"]])
    writer.writerow(["Staff Names", "|".join(data["Staff"])])

print("Scraping completed! Data saved to sanjivani_staff.csv")
# Out:
# Scraping completed! Data saved to sanjivani_staff.csv

# %%
import requests
from bs4 import BeautifulSoup

# ----------------------------
# URLs
# ----------------------------
HOME_URL = "https://www.sanjivanicoe.org.in"
DIRECTOR_URL = "https://www.sanjivanicoe.org.in/index.php/about-us/principal-s-desk"
IT_HOD_URL = "https://www.sanjivanicoe.org.in/index.php/department/information-technology/hod-s-desk"
IT_STAFF_URL = "https://www.sanjivanicoe.org.in/index.php/department/information-technology/faculty"

# ----------------------------
# Helper function
# ----------------------------
def get_soup(url):
    response = requests.get(url, timeout=10)
    response.raise_for_status()
    return BeautifulSoup(response.text, "html.parser")

print("\n========== COLLEGE INFORMATION ==========\n")

# ----------------------------
# 1. College Name
# ----------------------------
home_soup = get_soup(HOME_URL)
college_name = home_soup.title.text.strip()

print("1. College Name:")
print(college_name, "\n")

# ----------------------------
# 2. Director / Principal Name
# ----------------------------
director_soup = get_soup(DIRECTOR_URL)
director_name = "Not Found"

for line in director_soup.get_text(separator="\n").split("\n"):
    line = line.strip()
    if line.startswith("Dr.") or line.startswith("Prof."):
        director_name = line
        break

print("2. Director / Principal Name:")
print(director_name, "\n")

# ----------------------------
# 3. Department Name
# ----------------------------
print("3. Department Name:")
print("Information Technology\n")

# ----------------------------
# 4. HOD Name (IT)
# ----------------------------
hod_soup = get_soup(IT_HOD_URL)
hod_name = "Not Found"

for line in hod_soup.get_text(separator="\n").split("\n"):
    line = line.strip()
    if line.startswith("Dr.") or line.startswith("Prof."):
        hod_name = line
        break

print("4. HOD Name:")
print(hod_name, "\n")

# # ----------------------------
# # 5. Staff Names (IT)
# # ----------------------------
# print("5. IT Department Faculty Members:")
# if staff_names:
#     count = 1
#     for raw_name in sorted(staff_names):
#         final_name = faculty_mapping.get(raw_name, raw_name)
#         print(f"{count}. {final_name}")
#         count += 1
# else:
#     print("Faculty data not found")


print("\n========== END ==========\n")
# Out:
# ========== COLLEGE INFORMATION ==========
#
# 1. College Name:
# Sanjivani College of Engineering
#
# 2. Director / Principal Name:
# Dr. R. A. Kapgate
#
# 3. Department Name:
# Information Technology
#
# 4. HOD Name:
# Prof. Dr. Madhuri A.Jawale
#
#
# ========== END ==========

# %%
import requests
from bs4 import BeautifulSoup
import re

URL = "https://www.sanjivanicoe.org.in/index.php/department/information-technology/faculty"

response = requests.get(URL, timeout=10)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

text = soup.get_text(separator="\n")

faculty_names = []

# Regex for faculty names
pattern = re.compile(
    r"(Prof\. Dr\.|Dr\.|Prof\.|Mr\.|Mrs\.|Miss\.)\s+[A-Za-z.\s]"
)

for line in text.split("\n"):
    line = line.strip()
    if pattern.fullmatch(line):
        if line not in faculty_names:
            faculty_names.append(line)

print("\n======= IT DEPARTMENT FACULTY ==========\n")

if faculty_names:
    for i, name in enumerate(faculty_names, start=1):
        print(f"{i}. {name}")
else:
    print("Faculty data not found")

print("\n=======================================")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1423, in HTTPConnection.getresponse(self)
#    1422 try:
# -> 1423     response.begin()
#    1424 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     706 try:
# --> 707     return self._sock.recv_into(b)
#     708 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1103 if buffer is not None:
# -> 1104     return self._sslobj.read(len, buffer)
#    1105 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\util\retry.py:490, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     489 if read is False or method is None or not self._is_method_retryable(method):
# --> 490     raise reraise(type(error), error, _stacktrace)
#     491 elif read is not None:
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\urllib3\connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='www.sanjivanicoe.org.in', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[20], line 7
#       3 import re
#       5 URL = "https://www.sanjivanicoe.org.in/index.php/department/information-technology/faculty"
# ----> 7 response = requests.get(URL, timeout=10)
#       8 response.raise_for_status()
#      10 soup = BeautifulSoup(response.text, "html.parser")
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\B.Tech 3rd Year\ADS\.venv\Lib\site-packages\requests\adapters.py:690, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     688     raise SSLError(e, request=request)
#     689 elif isinstance(e, ReadTimeoutError):
# --> 690     raise ReadTimeout(e, request=request)
#     691 elif isinstance(e, _InvalidHeader):
#     692     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='www.sanjivanicoe.org.in', port=443): Read timed out. (read timeout=10)
